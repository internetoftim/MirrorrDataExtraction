# %%
import mirrorr_instagram_extractor
from mirrorr_instagram_extractor import InstaUser
from IPython.display import Image
import jsonpickle
import json
import time

def short_demo(userid):
    user = InstaUser(userid=userid)
    user.quick_demo()
    print(user.get_info())
    user.download_profile_pic()
    display(Image(tim_user.fileout))    
    user.screenshot_main()
    display(Image(user.fileout))
    user.screenshot_lower()
    time.sleep(0.3)
    user.screenshot_lower()
    display(Image(user.fileout))

# %%
tim_user = InstaUser(userid='taylorswift')

# %%
tim_user.quick_demo()

# %%
tim_user.followers
# Out:
# '112m'

# %%
tim_user.get_info()
# Out:
# {'userid': 'taylorswift',
#  'posts': '225',
#  'followers': '112m',
#  'following': '0',
#  'profile_pic_uri': 'https://scontent-hkg3-1.cdninstagram.com/vp/81a760c38d68de3b17e5508270a63186/5C5C71BF/t51.2885-19/s150x150/20969376_112654676087652_1378856425261891584_a.jpg'}

# %%
tim_user.download_profile_pic()
Image(tim_user.fileout)

# %%
tim_user.screenshot_main()
Image(tim_user.fileout)

# %%
tim_user.screenshot_lower()
Image(tim_user.fileout)

# %%
short_demo(userid='livelovebeirut')
# Out:
# {'userid': 'livelovebeirut', 'posts': '10,975', 'followers': '323k', 'following': '588', 'profile_pic_uri': 'https://scontent-hkg3-1.cdninstagram.com/vp/f4d66732ae1e51fc275bcae4d032a40a/5C4DA3A8/t51.2885-19/11821871_699562673481682_730349_a.jpg'}

# %%
from PIL import Image as IMG
import requests
from io import BytesIO

response = requests.get(tim_user.profile_pic_uri)
img = IMG.open(BytesIO(response.content))
img.save('thumbnail.jpg')

# file = cStringIO.StringIO(urllib.urlopen(tim_user.profile_pic_urio).read())
# img = Image.open(file)

# %%
Image('thumbnail.jpg')
